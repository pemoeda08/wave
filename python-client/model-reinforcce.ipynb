# %%
from mlagents_envs.environment import ActionTuple, UnityEnvironment
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel
import numpy as np
import torch

# %%
channel = EngineConfigurationChannel()

env = UnityEnvironment(file_name='./Wave', seed=1, side_channels=[channel])
channel.set_configuration_parameters(time_scale = 3.0)
print("WAVE environment created.")
# Out:
# WAVE environment created.

# %%
l1 = 38
l2 = 150
l3 = 150
l4 = 2

model = torch.nn.Sequential(
  torch.nn.Linear(l1, l2),
  torch.nn.ReLU(),
  torch.nn.Linear(l2,l3),
  torch.nn.ReLU(),
  torch.nn.Linear(l3,l4),
  torch.nn.Softmax(dim=1)
)
  
learning_rate = 5e-3
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def discount_rewards(rewards: np.ndarray, gamma):
    reversed = np.copy(rewards)[::-1]
    discounted_rewards = []
    for i, reward in enumerate(reversed):
        discounted_rewards.append(reward + (0 if i == 0 else reversed[i - 1]))
        reversed[i] = reward * gamma
        if i > 0:
            reversed[i] += reversed[i - 1] * gamma
    return np.array(discounted_rewards[::-1])

def loss_fn(predictions, rewards):
    return -1 * torch.sum(rewards * torch.log(predictions))

def preprocess_input(inp):
    return np.append(inp.obs[1], inp.obs[0], axis=1).reshape(-1)

def get_trajectories(model):
    states = []
    actions = []
    action_sets = []
    rewards = []

    env.reset()
    behavior_name = list(env.behavior_specs)[0]
    while True:
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        if (len(terminal_steps) > 0):
            break

        state = preprocess_input(decision_steps)

        states.append(state)
        pred = model(torch.Tensor(np.array([state])))
        action = np.random.choice(np.array([0, 1]), p=pred.detach().numpy().flatten())
        actions.append(action)
        action_tuple = ActionTuple()
        action_tuple.add_discrete(np.array([[action]]))
        env.set_actions(behavior_name, action_tuple)
        env.step()
        
        new_decision_steps, new_terminal_steps = env.get_steps(behavior_name)
        current_step = new_decision_steps if len(new_terminal_steps) == 0 else new_terminal_steps
        try:
            reward = current_step.reward[0]
        except:
            reward = 0
        rewards.append(float(reward))

    return torch.from_numpy(np.array(states)).float(), np.array(actions), np.array(rewards), np.array(action_sets)

# %%
EPOCH = 1000
GAMMA = 0.35

for i in range(EPOCH):
    states, actions, rewards, action_sets = get_trajectories(model)
    if states.shape[0] == 0:
        continue
    print(states.shape)
    predictions = model(states)
    cumulative_reward = np.sum(rewards)
    print(f'EPOCH {i}: cumulative reward {cumulative_reward}')
    discounted_rewards = torch.tensor(discount_rewards(rewards, GAMMA))
    print(discounted_rewards)

    actions = torch.tensor(actions.reshape(-1, 1)).long()
    prob_batch = predictions.gather(dim=1,index=actions).squeeze()
    loss = loss_fn(prob_batch, discounted_rewards)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# torch.Size([121, 38])
# EPOCH 0: cumulative reward -28.731335401535034
# tensor([  0.0565,   0.0587,   0.0685,   0.0780,   0.0872,   0.0960,   0.1045,
#           0.1127,   0.1207,   0.1283,   0.1357,   0.1428,   0.1497,   0.1563,
#           0.1627,   0.1689,   0.1749,   0.1806,   0.1862,   0.1916,   0.1967,
#           0.2017,   0.2065,   0.2112,   0.2157,   0.2200,   0.2242,   0.2282,
#           0.2321,   0.2359,   0.2395,   0.2430,   0.2463,   0.2496,   0.2527,
)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\Nathan\!SKRIPSI\code-2\model-reinforcce.ipynb Cell 5' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000004?line=1'>2</a> GAMMA = 0.35
#       <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000004?line=3'>4</a> for i in range(EPOCH):
# ----> <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000004?line=4'>5</a>     states, actions, rewards, action_sets = get_trajectories(model)
#       <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000004?line=5'>6</a>     if states.shape[0] == 0:
#       <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000004?line=6'>7</a>         continue
#
# e:\Nathan\!SKRIPSI\code-2\model-reinforcce.ipynb Cell 4' in get_trajectories(model)
#      <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000007?line=36'>37</a> action_tuple.add_discrete(np.array([[action]]))
#      <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000007?line=37'>38</a> env.set_actions(behavior_name, action_tuple)
# ---> <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000007?line=38'>39</a> env.step()
#      <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000007?line=40'>41</a> new_decision_steps, new_terminal_steps = env.get_steps(behavior_name)
#      <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000007?line=41'>42</a> current_step = new_decision_steps if len(new_terminal_steps) == 0 else new_terminal_steps
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\mlagents_envs\timers.py:305, in timed.<locals>.wrapped(*args, **kwargs)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/timers.py?line=302'>303</a> def wrapped(*args, **kwargs):
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/timers.py?line=303'>304</a>     with hierarchical_timer(func.__qualname__):
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/timers.py?line=304'>305</a>         return func(*args, **kwargs)
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\mlagents_envs\environment.py:333, in UnityEnvironment.step(self)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=330'>331</a> step_input = self._generate_step_input(self._env_actions)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=331'>332</a> with hierarchical_timer("communicator.exchange"):
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=332'>333</a>     outputs = self._communicator.exchange(step_input, self._poll_process)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=333'>334</a> if outputs is None:
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=334'>335</a>     raise UnityCommunicatorStoppedException("Communicator has exited.")
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\mlagents_envs\rpc_communicator.py:137, in RpcCommunicator.exchange(self, inputs, poll_callback)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=134'>135</a> message.unity_input.CopyFrom(inputs)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=135'>136</a> self.unity_to_external.parent_conn.send(message)
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=136'>137</a> self.poll_for_timeout(poll_callback)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=137'>138</a> output = self.unity_to_external.parent_conn.recv()
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=138'>139</a> if output.header.status != 200:
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\mlagents_envs\rpc_communicator.py:103, in RpcCommunicator.poll_for_timeout(self, poll_callback)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=100'>101</a> callback_timeout_wait = self.timeout_wait // 10
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=101'>102</a> while time.monotonic() < deadline:
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=102'>103</a>     if self.unity_to_external.parent_conn.poll(callback_timeout_wait):
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=103'>104</a>         # Got an acknowledgment from the connection
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=104'>105</a>         return
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=105'>106</a>     if poll_callback:
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=106'>107</a>         # Fire the callback - if it detects something wrong, it should raise an exception.
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\multiprocessing\connection.py:262, in _ConnectionBase.poll(self, timeout)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=259'>260</a> self._check_closed()
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=260'>261</a> self._check_readable()
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=261'>262</a> return self._poll(timeout)
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\multiprocessing\connection.py:335, in PipeConnection._poll(self, timeout)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=331'>332</a> if (self._got_empty_message or
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=332'>333</a>             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=333'>334</a>     return True
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=334'>335</a> return bool(wait([self], timeout))
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\multiprocessing\connection.py:884, in wait(object_list, timeout)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=880'>881</a>                 ready_objects.add(o)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=881'>882</a>                 timeout = 0
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=883'>884</a>     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=884'>885</a> finally:
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=885'>886</a>     # request that overlapped reads stop
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=886'>887</a>     for ov in ov_list:
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\multiprocessing\connection.py:816, in _exhaustive_wait(handles, timeout)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=813'>814</a> ready = []
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=814'>815</a> while L:
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=815'>816</a>     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=816'>817</a>     if res == WAIT_TIMEOUT:
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/multiprocessing/connection.py?line=817'>818</a>         break
#
# KeyboardInterrupt:

# %%
env = UnityEnvironment(file_name='./Wave', seed=1)
print("WAVE environment created.")

env.reset()
while True:
    behavior_name = list(env.behavior_specs)[0]

    decision_steps, terminal_steps = env.get_steps(behavior_name)
    print(decision_steps.obs)
    if (len(terminal_steps) > 0):
        break

    preds = model(torch.Tensor(preprocess_input(decision_steps))).detach().numpy()
    print(preds)
    action = np.argmax(preds)
    action_tuple = ActionTuple()
    action_tuple.add_discrete(np.array([[action]]))
    env.set_actions(behavior_name, action_tuple)
    env.step()

env.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\mlagents_envs\rpc_communicator.py:68, in RpcCommunicator.create_server(self)
#      <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=65'>66</a> # Using unspecified address, which means that grpc is communicating on all IPs
#      <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=66'>67</a> # This is so that the docker container can connect.
# ---> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=67'>68</a> self.server.add_insecure_port("[::]:" + str(self.port))
#      <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=68'>69</a> self.server.start()
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\grpc\_server.py:969, in _Server.add_insecure_port(self, address)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/grpc/_server.py?line=967'>968</a> def add_insecure_port(self, address):
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/grpc/_server.py?line=968'>969</a>     return _common.validate_port_binding_result(
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/grpc/_server.py?line=969'>970</a>         address, _add_insecure_port(self._state, _common.encode(address)))
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\grpc\_common.py:166, in validate_port_binding_result(address, port)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/grpc/_common.py?line=162'>163</a> if port == 0:
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/grpc/_common.py?line=163'>164</a>     # The Core API doesn't return a failure message. The best we can do
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/grpc/_common.py?line=164'>165</a>     # is raising an exception to prevent further confusion.
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/grpc/_common.py?line=165'>166</a>     raise RuntimeError(_ERROR_MESSAGE_PORT_BINDING_FAILED % address)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/grpc/_common.py?line=166'>167</a> else:
#
# RuntimeError: Failed to bind to address [::]:5005; set GRPC_VERBOSITY=debug environment variable to see detailed error message.
#
# During handling of the above exception, another exception occurred:
#
# UnityWorkerInUseException                 Traceback (most recent call last)
# e:\Nathan\!SKRIPSI\code-2\model-reinforcce.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000005?line=0'>1</a> env = UnityEnvironment(file_name='./Wave', seed=1)
#       <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000005?line=1'>2</a> print("WAVE environment created.")
#       <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/code-2/model-reinforcce.ipynb#ch0000005?line=3'>4</a> env.reset()
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\mlagents_envs\environment.py:187, in UnityEnvironment.__init__(self, file_name, worker_id, base_port, seed, no_graphics, timeout_wait, additional_args, side_channels, log_folder)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=184'>185</a> self._process: Optional[subprocess.Popen] = None
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=185'>186</a> self._timeout_wait: int = timeout_wait
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=186'>187</a> self._communicator = self._get_communicator(worker_id, base_port, timeout_wait)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=187'>188</a> self._worker_id = worker_id
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=188'>189</a> self._side_channel_manager = SideChannelManager(side_channels)
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\mlagents_envs\environment.py:252, in UnityEnvironment._get_communicator(worker_id, base_port, timeout_wait)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=249'>250</a> @staticmethod
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=250'>251</a> def _get_communicator(worker_id, base_port, timeout_wait):
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/environment.py?line=251'>252</a>     return RpcCommunicator(worker_id, base_port, timeout_wait)
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\mlagents_envs\rpc_communicator.py:51, in RpcCommunicator.__init__(self, worker_id, base_port, timeout_wait)
#      <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=48'>49</a> self.unity_to_external = None
#      <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=49'>50</a> self.is_open = False
# ---> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=50'>51</a> self.create_server()
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\mlagents_envs\rpc_communicator.py:72, in RpcCommunicator.create_server(self)
#      <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=69'>70</a>     self.is_open = True
#      <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=70'>71</a> except Exception:
# ---> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/mlagents_envs/rpc_communicator.py?line=71'>72</a>     raise UnityWorkerInUseException(self.worker_id)
#
# UnityWorkerInUseException: Couldn't start socket communication because worker number 0 is still in use. You may need to manually close a previously opened environment or use a different worker number.

# %%
env.close()
